# %% [markdown]
# # Exploratory Data Analysis(EDA),Topic modelling anf sentimetal Analysis
#
# -
# ## Data analysis
# ### Data Insight
# - First read the Json data and convert it to pandas DataFrame.
# - Generate a information about data
# - Generate a report regarding types of the data in each column
# - Identify the missing and NA values in each column.
# - identify the target value that is to be predicted
#
#
# ## 2. Data preparation
#
#
# - Handling the missing/NA value using various techniques(replacement, etc)
# - Encoding categorical values (labelencoder, onehotencoder, etc)
# - Normalizing/standardizing the numerical value
# - Determining the linear relationships between feature variables(heatmap, correlation matrix, pairplots) what called    correlation
# - Learn the distribution of data points to identify the outliers, and how do they affect overall distribution. Ex. tools: box plot
# - Dimensionality reduction and feature engineering fo minimize the dimensionalit curse effect
#
#
# ## 3. Modeling
#
# - Classification model should be selected
# - Split the dataset into train and test set
# - Build Model the model using the train set
#
# ## 4. Metrics
#
# - since the task is classification, we have to use a evaluation metrics that are designed for classificagtion task (accuracy, precision, f1 score)
#
# ## 5. How success
#
# - Do the models solve the business problem and what the metrics are telling
#
# # Expected Challenges
#
# - Computational resource constraint
# - Slow response from the stakeholders

# %% [markdown]
# ## 1. Importing the necessary python packages

# %%
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from wordcloud import STOPWORDS,WordCloud
from gensim import corpora
import pandas as pd
import statistics
import string
import os
import re
import sys

sys.path.append(os.path.abspath(os.path.join("./..")))

# custom modules from Day-1
from extract_dataframe import read_json, TweetDfExtractor
from clean_tweets_dataframe import Clean_Tweets
from preprocess_tweet_data import DataPreparation

# %% [markdown]
# ## 2. Data acquisition
# - From the json file given on Day 1 we can extract tweet_data using the extract_dataframe
#  1. First tweet_list is generated from the json using read_json function
#  2. From the list tweet_data DataFrame is created

# %%
_, tweet_list = read_json("../data/global_twitter_data.json")
tweet = TweetDfExtractor(tweet_list)
tweet_data = tweet.get_tweet_df(save=False)
tweet_data.head(50)
# Out:
#                         created_at  \
# 0   Sun Aug 07 22:31:20 +0000 2022
# 1   Sun Aug 07 22:31:16 +0000 2022
# 2   Sun Aug 07 22:31:07 +0000 2022
# 3   Sun Aug 07 22:31:06 +0000 2022
# 4   Sun Aug 07 22:31:04 +0000 2022
# 5   Sun Aug 07 22:31:02 +0000 2022
# 6   Sun Aug 07 22:30:59 +0000 2022
# 7   Sun Aug 07 22:30:59 +0000 2022
# 8   Sun Aug 07 22:30:50 +0000 2022
# 9   Sun Aug 07 22:30:45 +0000 2022
# 10  Sun Aug 07 22:30:41 +0000 2022
# 11  Sun Aug 07 22:30:35 +0000 2022
# 12  Sun Aug 07 22:30:35 +0000 2022
# 13  Sun Aug 07 22:30:29 +0000 2022
# 14  Sun Aug 07 22:30:27 +0000 2022
# 15  Sun Aug 07 22:30:25 +0000 2022
# 16  Sun Aug 07 22:30:15 +0000 2022
# 17  Sun Aug 07 22:30:10 +0000 2022
# 18  Sun Aug 07 22:30:06 +0000 2022
# 19  Sun Aug 07 22:30:01 +0000 2022
# 20  Sun Aug 07 22:29:53 +0000 2022
# 21  Sun Aug 07 22:29:07 +0000 2022
# 22  Sun Aug 07 22:28:58 +0000 2022
# 23  Sun Aug 07 22:28:54 +0000 2022
# 24  Sun Aug 07 22:28:44 +0000 2022
# 25  Sun Aug 07 22:28:34 +0000 2022
# 26  Sun Aug 07 22:28:32 +0000 2022
# 27  Sun Aug 07 22:28:27 +0000 2022
# 28  Sun Aug 07 22:28:07 +0000 2022
# 29  Sun Aug 07 22:28:02 +0000 2022
# 30  Sun Aug 07 22:27:54 +0000 2022
# 31  Sun Aug 07 22:27:49 +0000 2022
# 32  Sun Aug 07 22:27:47 +0000 2022
# 33  Sun Aug 07 22:27:16 +0000 2022
# 34  Sun Aug 07 22:27:02 +0000 2022
# 35  Sun Aug 07 22:26:40 +0000 2022
# 36  Sun Aug 07 22:26:25 +0000 2022
# 37  Sun Aug 07 22:26:23 +0000 2022
# 38  Sun Aug 07 22:25:57 +0000 2022
# 39  Sun Aug 07 22:25:37 +0000 2022
# 40  Sun Aug 07 22:25:34 +0000 2022
# 41  Sun Aug 07 22:25:14 +0000 2022
# 42  Sun Aug 07 22:25:13 +0000 2022
# 43  Sun Aug 07 22:25:05 +0000 2022
# 44  Sun Aug 07 22:25:02 +0000 2022
# 45  Sun Aug 07 22:25:00 +0000 2022
# 46  Sun Aug 07 22:24:59 +0000 2022
# 47  Sun Aug 07 22:24:57 +0000 2022
# 48  Sun Aug 07 22:24:44 +0000 2022
# 49  Sun Aug 07 22:24:40 +0000 2022
#
#                                                source  \
# 0   <a href="http://twitter.com/download/android" ...
# 1   <a href="http://twitter.com/download/android" ...
# 2   <a href="http://twitter.com/download/android" ...
# 3   <a href="http://twitter.com/download/android" ...
# 4   <a href="http://twitter.com/download/iphone" r...
# 5   <a href="http://twitter.com/download/android" ...
# 6   <a href="http://twitter.com/download/android" ...
# 7   <a href="http://twitter.com/download/android" ...
# 8   <a href="http://twitter.com/download/android" ...
# 9   <a href="https://mobile.twitter.com" rel="nofo...
# 10  <a href="http://twitter.com/download/android" ...
# 11  <a href="https://mobile.twitter.com" rel="nofo...
# 12  <a href="http://twitter.com/download/android" ...
# 13  <a href="http://twitter.com/download/android" ...
# 14  <a href="http://twitter.com/download/android" ...
# 15  <a href="http://twitter.com/download/android" ...
# 16  <a href="http://twitter.com/download/android" ...
# 17  <a href="http://twitter.com/download/iphone" r...
# 18  <a href="https://covid19travel.com" rel="nofol...
# 19  <a href="https://buffer.com" rel="nofollow">Bu...
# 20  <a href="http://twitter.com/download/iphone" r...
# 21  <a href="http://twitter.com/download/android" ...
# 22  <a href="https://mobile.twitter.com" rel="nofo...
# 23  <a href="http://twitter.com/download/iphone" r...
# 24  <a href="http://twitter.com/download/android" ...
# 25  <a href="http://twitter.com/download/iphone" r...
# 26  <a href="http://twitter.com/download/iphone" r...
# 27  <a href="http://twitter.com/#!/download/ipad" ...
# 28  <a href="http://twitter.com/download/android" ...
# 29  <a href="https://mobile.twitter.com" rel="nofo...
# 30  <a href="http://twitter.com/download/iphone" r...
# 31  <a href="http://twitter.com/download/android" ...
# 32  <a href="http://twitter.com/download/android" ...
# 33  <a href="http://twitter.com/download/android" ...
# 34  <a href="http://twitter.com/download/iphone" r...
# 35  <a href="http://twitter.com/download/android" ...
# 36  <a href="http://twitter.com/download/android" ...
# 37  <a href="http://twitter.com/download/iphone" r...
# 38  <a href="http://twitter.com/download/android" ...
# 39  <a href="http://twitter.com/download/android" ...
# 40  <a href="http://twitter.com/download/iphone" r...
# 41  <a href="http://twitter.com/download/iphone" r...
# 42  <a href="http://twitter.com/download/android" ...
# 43  <a href="https://help.twitter.com/en/using-twi...
# 44  <a href="http://twitter.com/download/android" ...
# 45  <a href="https://mobile.twitter.com" rel="nofo...
# 46  <a href="https://mobile.twitter.com" rel="nofo...
# 47  <a href="http://twitter.com/download/iphone" r...
# 48  <a href="http://twitter.com/download/android" ...
# 49  <a href="http://twitter.com/download/android" ...
#
#                                         original_text      polarity  \
# 0   RT @i_ameztoy: Extra random image (I):\n\nLets... -1.250000e-01
# 1   RT @IndoPac_Info: #China's media explains the ... -1.000000e-01
# 2   China even cut off communication, they don't a...  0.000000e+00
# 3   Putin to #XiJinping : I told you my friend, Ta...  1.000000e-01
# 4   RT @ChinaUncensored: I’m sorry, I thought Taiw... -6.938894e-18
# 5   RT @benedictrogers: We must not let this happe...  2.000000e-01
# 6   RT @TGTM_Official: What kind of country can co...  1.583333e-01
# 7   RT @ChinaInfo777: #PinkFloyd singer Roger Wate...  0.000000e+00
# 8   RT @AmbQinGang: China's SC&amp;FM Wang Yi elab...  0.000000e+00
# 9   RT @CGMeifangZhang: Chinese ambassador to the ...  2.000000e-01
# 10  RT @CGMeifangZhang: #Latest When the PLA condu...  5.555556e-02
# 11  Wilson Chinonso Blog: Nigerian tribes, the lis...  0.000000e+00
# 12  RT @IndoPac_Info: A good infographic of #China...  7.000000e-01
# 13  RT @shen_shiwei: Roger Waters: "They're (Chine...  1.000000e-01
# 14  RT @SpokespersonCHN: Baidu Maps show that ther...  0.000000e+00
# 15  RT @Decent_az001: The #Marvininu project speak...  2.714286e-01
# 16  RT @EagleNews: China's largest-ever Taiwan mil... -1.000000e-01
# 17  RT @timand2037: Former colonial regimes - now ... -2.000000e-01
# 18  RT @odisseoisback: #Corfu #Greece🇬🇷\n#Summer #...  0.000000e+00
# 19  27.89US $ 17% OFF|Usb Condenser Microphone For...  0.000000e+00
# 20  RT @terror_alarm: 🚨🇨🇳🇹🇼China now has #Taiwan s... -1.000000e-01
# 21  RT @IndoPac_Info: Yesterday, #Taiwanese army f...  0.000000e+00
# 22  RT @CGMeifangZhang: "#Taiwan is part of China....  1.333333e-01
# 23  RT @CGTNOfficial: Day 3 of PLA's live-fire dri...  0.000000e+00
# 24  RT @euobs: [Opinion] #Pelosi's visit to #Taiwa... -3.750000e-01
# 25  @apple @tim_cook REALLY?? \n\nhttps://t.co/vOG...  2.000000e-01
# 26  @AndrewJBates46 #carriedInterest #LoisLerner #... -5.000000e-01
# 27  Taiwan is a city of China, that acts as a non-...  0.000000e+00
# 28  RT @CGMeifangZhang: #US House Speaker Nancy #P...  0.000000e+00
# 29  RT @CGMeifangZhang: Responding to a CNN report...  1.000000e-01
# 30  RT @IndoPac_Info: #China's media explains the ...  6.938894e-18
# 31  RT @CGMeifangZhang: Biden said he can't preven... -1.300000e-01
# 32  RT @revmahoney: How do we know how the CCP wou...  4.333333e-01
# 33  RT @MAKSIMYQY: If Hawaii separatists want to e...  0.000000e+00
# 34  RT @SpokespersonCHN: "#Taiwan is part of China...  1.333333e-01
# 35  RT @SpokespersonCHN: "#Taiwan is part of China...  1.333333e-01
# 36  RT @ChinaInfo777: #PinkFloyd Roger Waters tell...  0.000000e+00
# 37  RT @IndoPac_Info: 66 #Chinese military aircraf... -6.666667e-02
# 38  @BarkingMaad @EnemyInAState The #Taiwan #Taiwa...  6.250000e-01
# 39  RT @WilliamYang120: "For too long, #Taiwan has... -2.500000e-02
# 40  RT @Veronic59122266: Nancy Pelosi is willing t...  8.333333e-02
# 41  If you’re against capitalism when China is ric... -1.562500e-01
# 42  RT @globaltimesnews: #GTGraphic: 160+ countrie...  0.000000e+00
# 43  RT @odisseoisback: #Corfu #Greece🇬🇷\n#Summer #...  0.000000e+00
# 44  RT @SpokespersonCHN: "#Taiwan is part of China...  1.333333e-01
# 45  #Corfu #Greece🇬🇷\n#Summer #Beaches #Travel #Ex...  1.363636e-01
# 46  The U.S. has substantially increased defense &... -7.500000e-02
# 47                #taiwan shouod be a member of #nato  0.000000e+00
# 48  RT @benedictrogers: We must not let this happe...  2.000000e-01
# 49  @BarkingMaad @EnemyInAState I think the only w...  0.000000e+00
#
#     subjectivity lang  favorite_count  retweet_count  original_author  \
# 0       0.190625   en               0              2        i_ameztoy
# 1       0.100000   en               0            201            ZIisq
# 2       0.000000   en               0              0        Fin21Free
# 3       0.350000   en               0              0        Fin21Free
# 4       0.556250   en               0            381   VizziniDolores
# 5       0.500000   en               0             36  GraceCh15554845
# 6       0.800000   en               0            411      Philipkuma1
# 7       0.000000   en               0              5        nhohn2011
# 8       0.000000   en               0            239  ClaudioColomaRI
# 9       0.375000   en               0             25        jmarzola1
# 10      0.855556   en               0             11     xuejianosaka
# 11      0.000000   en               1              0     wilson_chnns
# 12      0.600000   en               0            183            ZIisq
# 13      0.450000   en               0              7   Aurora20288302
# 14      0.000000   en               0            358        Rocky4533
# 15      0.296429   en               0             20      Foxy_Jaylad
# 16      0.100000   en               0              1     fortunefrien
# 17      0.300000   en               0            128    henok_tekeste
# 18      0.000000   en               0              2   Covid19Travel_
# 19      0.000000   en               0              0     doos94619918
# 20      0.166667   en               0            112   DjPeaceOfMind1
# 21      0.000000   en               0             74       Cyclorient
# 22      0.433333   en               0            109         arjlight
# 23      0.000000   en               0             26     kwame_seeker
# 24      1.000000   en               0              4       Cyclorient
# 25      0.200000   en               0              0          rjj_jim
# 26      0.750000   en               0              0     LarsonKellie
# 27      0.650000   en               0              0    robinholdings
# 28      0.000000   en               0            121    josearias3329
# 29      0.300000   en               0            128  MauricioLoren14
# 30      0.241667   en               0            112         kisdurka
# 31      0.115000   en               0             27    huang17239678
# 32      0.833333   en               0              5  JohnCha85102303
# 33      0.125000   en               0             26        wcgkyyhjx
# 34      0.433333   en               0            669        Martahjoy
# 35      0.433333   en               0            669       Attomikdog
# 36      0.000000   en               0              5        nhohn2011
# 37      0.066667   en               0             43     xiaohuaSong3
# 38      0.500000   en               1              0    BenEndCOVID19
# 39      0.200000   en               0             84  hoggothoaryhost
# 40      0.616667   en               0           1897    robbie_robbi1
# 41      0.437500   en               0              0  marketdaytrader
# 42      0.000000   en               0            165   GreatMundungus
# 43      0.000000   en               0              2    hephaistos_ai
# 44      0.433333   en               0            669  patricialeahy54
# 45      0.454545   en               0              2    odisseoisback
# 46      0.316667   en               0              0        RenKeNews
# 47      0.000000   en               0              0   michaelsgordon
# 48      0.500000   en               0             36  hoggothoaryhost
# 49      1.000000   en               1              0    BenEndCOVID19
#
#     followers_count  friends_count possibly_sensitive  \
# 0             20497           2621               None
# 1                65            272               None
# 2                85            392               None
# 3                85            392               None
# 4               910           2608               None
# 5               207             54              False
# 6                12            264               None
# 7               870            508               None
# 8               127            263               None
# 9               213            877               None
# 10            45242           1505               None
# 11               28            265              False
# 12               65            272              False
# 13                9            178               None
# 14              265            627               None
# 15              669            461               None
# 16              336           1026               None
# 17             1165           2542               None
# 18               27              0              False
# 19             1936           4792              False
# 20               21            131               None
# 21              639            642               None
# 22              150            120               None
# 23               45            419              False
# 24              639            642               None
# 25               69            211               True
# 26              636           4002              False
# 27             4624              3               None
# 28              160            219               None
# 29              433            482               None
# 30              117            316               None
# 31                8             54               None
# 32              120            158               None
# 33              266            597               None
# 34              823            597               None
# 35              151            701               None
# 36              870            508              False
# 37              243             87               None
# 38              550           1207               None
# 39               44             60              False
# 40              808           3650               None
# 41               42             69               None
# 42              177            293               None
# 43             4161            208              False
# 44              702           2793               None
# 45              332            845              False
# 46            48203            422               None
# 47              608           4919               None
# 48               44             60              False
# 49              550           1207               None
#
#                                              hashtags  \
# 0                                              [City]
# 1                                     [China, Taiwan]
# 2                                         [XiJinping]
# 3                                         [XiJinping]
# 4
# 5                                            [Taiwan]
# 6                                [Taiwan, TsaiIngwen]
# 7                          [PinkFloyd, Taiwan, China]
# 8                                            [Taiwan]
# 9                        [USA, Pelosi, Taiwan, China]
# 10                                   [Latest, Taiwan]
# 11                    [China, ChinaTaiwan, ManUnited]
# 12                 [China, Taiwan, ChinaTaiwanCrisis]
# 13                                           [Taiwan]
# 14
# 15                                        [Marvininu]
# 16     [china, diplomacy, Militarydrills, Taiwan, US]
# 17                                            [China]
# 18  [Corfu, Greece, Summer, Beaches, Travel, Excur...
# 19  [aliexpress, USA, uk, RT, Europe, UnitedStates...
# 20                                           [Taiwan]
# 21                               [Taiwanese, Chinese]
# 22                                           [Taiwan]
# 23                                           [Taiwan]
# 24                                   [Pelosi, Taiwan]
# 25                                    [Apple, Taiwan]
# 26       [carriedInterest, LoisLerner, Pelosi, liars]
# 27  [WWIII, USandChina, Tradewar, China, geopoliti...
# 28                                       [US, Pelosi]
# 29                                           [Taiwan]
# 30                                    [China, Taiwan]
# 31                                   [Pelosi, Taiwan]
# 32
# 33
# 34                                           [Taiwan]
# 35                                           [Taiwan]
# 36                         [PinkFloyd, Taiwan, China]
# 37                                  [Chinese, Taiwan]
# 38  [Taiwan, TaiwanStraitsCrisis, ovenready, monke...
# 39                                           [Taiwan]
# 40
# 41                           [Xinjiang, Taiwan, Evil]
# 42                                        [GTGraphic]
# 43  [Corfu, Greece, Summer, Beaches, Travel, Excur...
# 44                                           [Taiwan]
# 45  [Corfu, Greece, Summer, Beaches, Travel, Excur...
# 46                                    [Taiwan, China]
# 47                                     [taiwan, nato]
# 48                                           [Taiwan]
# 49  [nightmare, Fascism, China, Taiwan, KimJongUn,...
#
#                    user_mentions                           place
# 0                    [i_ameztoy]
# 1                 [IndoPac_Info]
# 2                  [ZelenskyyUa]                     Netherlands
# 3                                                    Netherlands
# 4              [ChinaUncensored]                  Ayent, Schweiz
# 5               [benedictrogers]             Melbourne, Victoria
# 6                [TGTM_Official]
# 7                 [ChinaInfo777]                    Florida, USA
# 8                   [AmbQinGang]             El mundo periférico
# 9               [CGMeifangZhang]
# 10              [CGMeifangZhang]
# 11                                             Imo State Nigeria
# 12                [IndoPac_Info]
# 13                 [shen_shiwei]
# 14             [SpokespersonCHN]
# 15                [Decent_az001]
# 16                   [EagleNews]  San Jose Del Monte, Central Lu
# 17                  [timand2037]
# 18               [odisseoisback]
# 19                                      United States New York,
# 20                [terror_alarm]
# 21                [IndoPac_Info]                     TOKYO,JAPAN
# 22              [CGMeifangZhang]
# 23                [CGTNOfficial]
# 24                       [euobs]                     TOKYO,JAPAN
# 25             [Apple, tim_cook]
# 26              [AndrewJBates46]
# 27
# 28              [CGMeifangZhang]
# 29              [CGMeifangZhang]                Gravatal, Brasil
# 30                [IndoPac_Info]                          Prague
# 31              [CGMeifangZhang]
# 32                  [revmahoney]
# 33                   [MAKSIMYQY]                            Amoi
# 34             [SpokespersonCHN]                        Ethiopia
# 35             [SpokespersonCHN]                  svemirski brod
# 36                [ChinaInfo777]                    Florida, USA
# 37                [IndoPac_Info]
# 38  [BarkingMaad, EnemyInAState]                  United Kingdom
# 39              [WilliamYang120]                       Hong Kong
# 40             [Veronic59122266]
# 41
# 42             [globaltimesnews]                      Oxford, UK
# 43               [odisseoisback]                           Paris
# 44             [SpokespersonCHN]                   United States
# 45                                       Brindisi---Corfu---Moon
# 46                                             Brussels, Belgium
# 47                                   Wuhan Institute of Virology
# 48              [benedictrogers]                       Hong Kong
# 49  [BarkingMaad, EnemyInAState]                  United Kingdom

# %%
# print the information regarding each columns in dataframe
tweet_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22000 entries, 0 to 21999
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   created_at          22000 non-null  object
#  1   source              22000 non-null  object
#  2   original_text       22000 non-null  object
#  3   polarity            22000 non-null  float64
#  4   subjectivity        22000 non-null  float64
#  5   lang                22000 non-null  object
#  6   favorite_count      22000 non-null  int64
#  7   retweet_count       22000 non-null  int64
#  8   original_author     22000 non-null  object
#  9   followers_count     22000 non-null  int64
#  10  friends_count       22000 non-null  int64
#  11  possibly_sensitive  6191 non-null   object
#  12  hashtags            22000 non-null  object
#  13  user_mentions       22000 non-null  object
#  14  place               22000 non-null  object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 2.5+ MB

# %% [markdown]
# ### missing values
# - Identify the columns with missing value
# - Draw the missing values count on barchart

# %%
missing_values = tweet_data.isnull().sum()
print(f"Missing value(s) count: \n{missing_values}")
# Out:
# Missing value(s) count:
# created_at                0
# source                    0
# original_text             0
# polarity                  0
# subjectivity              0
# lang                      0
# favorite_count            0
# retweet_count             0
# original_author           0
# followers_count           0
# friends_count             0
# possibly_sensitive    15809
# hashtags                  0
# user_mentions             0
# place                     0
# dtype: int64

# %%
fig = missing_values.plot(kind='bar',fontsize=12, figsize=(10, 6), rot=45).get_figure()
fig.savefig("missing_values_bar_chart.png")

# %% [markdown]
# ### uni-variate Analysis on Hashtags

# %%
#Method to find hashtags from tweets
def find_hashtags(tweet):
    return re.findall('(#[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %%
# update Hashtag column with hashtags extracted from Orignal_text columon
tweet_data['hashtags'] = tweet_data['original_text'].apply(find_hashtags)

# take the rows from the hashtag columns where there are actually hashtags
hashtags_list_df = tweet_data.loc[
                       tweet_data.hashtags.apply(
                           lambda hashtags_list: hashtags_list !=[]
                       ),['hashtags']]

hashtags_list_df
# Out:
#                                     hashtags
# 0                               [#City, #Ta]
# 1                          [#China, #Taiwan]
# 2                               [#XiJinping]
# 3                               [#XiJinping]
# 5                                  [#Taiwan]
# ...                                      ...
# 21995  [#China, #Taiwan, #ChinaTaiwanCrisis]
# 21996  [#China, #Taiwan, #ChinaTaiwanCrisis]
# 21997                              [#Pelosi]
# 21998                      [#Taiwan, #China]
# 21999                      [#Taiwan, #China]
#
# [19408 rows x 1 columns]

# %%
#create dataframe where each use of hashtag gets its own row
flattened_hashtags_df = pd.DataFrame(
    [hashtag for hashtags_list in hashtags_list_df.hashtags
    for hashtag in hashtags_list],
    columns=['hashtag'])

# %%
#add flatten_hashtags to tweet_df
tweet_data["flattened_hashtags"]= flattened_hashtags_df
tweet_data.head()
# Out:
#                        created_at  \
# 0  Sun Aug 07 22:31:20 +0000 2022
# 1  Sun Aug 07 22:31:16 +0000 2022
# 2  Sun Aug 07 22:31:07 +0000 2022
# 3  Sun Aug 07 22:31:06 +0000 2022
# 4  Sun Aug 07 22:31:04 +0000 2022
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                        original_text      polarity  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets... -1.250000e-01
# 1  RT @IndoPac_Info: #China's media explains the ... -1.000000e-01
# 2  China even cut off communication, they don't a...  0.000000e+00
# 3  Putin to #XiJinping : I told you my friend, Ta...  1.000000e-01
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw... -6.938894e-18
#
#    subjectivity lang  favorite_count  retweet_count original_author  \
# 0      0.190625   en               0              2       i_ameztoy
# 1      0.100000   en               0            201           ZIisq
# 2      0.000000   en               0              0       Fin21Free
# 3      0.350000   en               0              0       Fin21Free
# 4      0.556250   en               0            381  VizziniDolores
#
#    followers_count  friends_count possibly_sensitive           hashtags  \
# 0            20497           2621               None       [#City, #Ta]
# 1               65            272               None  [#China, #Taiwan]
# 2               85            392               None       [#XiJinping]
# 3               85            392               None       [#XiJinping]
# 4              910           2608               None                 []
#
#        user_mentions           place flattened_hashtags
# 0        [i_ameztoy]                              #City
# 1     [IndoPac_Info]                                #Ta
# 2      [ZelenskyyUa]     Netherlands             #China
# 3                        Netherlands            #Taiwan
# 4  [ChinaUncensored]  Ayent, Schweiz         #XiJinping

# %%
# To plot Top 20 Hashtags
tweet_data['flattened_hashtags'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Analyzing the user mentions mentions

# %%
#Method to find hashtags from tweets
def find_hashtags(tweet):
    return re.findall('(@[A-Za-z]+[A-Za-z0-9-_]+)', tweet)

# %%
# update Hashtag column with hashtags extracted from Orignal_text columon
tweet_data['user_mentions'] = tweet_data['original_text'].apply(find_hashtags)

# take the rows from the hashtag columns where there are actually hashtags
user_mentions_list_df = tweet_data.loc[
                       tweet_data.user_mentions.apply(
                           lambda user_mentions_list_df: user_mentions_list_df !=[]
                       ),['user_mentions']]
user_mentions_list_df
# Out:
#             user_mentions
# 0            [@i_ameztoy]
# 1         [@IndoPac_Info]
# 2          [@ZelenskyyUa]
# 4      [@ChinaUncensored]
# 5       [@benedictrogers]
# ...                   ...
# 21995     [@IndoPac_Info]
# 21996     [@IndoPac_Info]
# 21997          [@Reuters]
# 21998     [@IndoPac_Info]
# 21999     [@IndoPac_Info]
#
# [18613 rows x 1 columns]

# %%
#create dataframe where each use of hashtag gets its own row
flattened_user_mentions_df = pd.DataFrame(
    [user_mention for user_mentions_list in user_mentions_list_df.user_mentions
    for user_mention in user_mentions_list],
    columns=['user_mentions'])

# %%
#add flatten_hashtags to tweet_df
tweet_data["flattened_user_mentions"]= flattened_user_mentions_df
tweet_data.head()
# Out:
#                        created_at  \
# 0  Sun Aug 07 22:31:20 +0000 2022
# 1  Sun Aug 07 22:31:16 +0000 2022
# 2  Sun Aug 07 22:31:07 +0000 2022
# 3  Sun Aug 07 22:31:06 +0000 2022
# 4  Sun Aug 07 22:31:04 +0000 2022
#
#                                               source  \
# 0  <a href="http://twitter.com/download/android" ...
# 1  <a href="http://twitter.com/download/android" ...
# 2  <a href="http://twitter.com/download/android" ...
# 3  <a href="http://twitter.com/download/android" ...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                        original_text      polarity  \
# 0  RT @i_ameztoy: Extra random image (I):\n\nLets... -1.250000e-01
# 1  RT @IndoPac_Info: #China's media explains the ... -1.000000e-01
# 2  China even cut off communication, they don't a...  0.000000e+00
# 3  Putin to #XiJinping : I told you my friend, Ta...  1.000000e-01
# 4  RT @ChinaUncensored: I’m sorry, I thought Taiw... -6.938894e-18
#
#    subjectivity lang  favorite_count  retweet_count original_author  \
# 0      0.190625   en               0              2       i_ameztoy
# 1      0.100000   en               0            201           ZIisq
# 2      0.000000   en               0              0       Fin21Free
# 3      0.350000   en               0              0       Fin21Free
# 4      0.556250   en               0            381  VizziniDolores
#
#    followers_count  friends_count possibly_sensitive           hashtags  \
# 0            20497           2621               None       [#City, #Ta]
# 1               65            272               None  [#China, #Taiwan]
# 2               85            392               None       [#XiJinping]
# 3               85            392               None       [#XiJinping]
# 4              910           2608               None                 []
#
#         user_mentions           place flattened_hashtags  \
# 0        [@i_ameztoy]                              #City
# 1     [@IndoPac_Info]                                #Ta
# 2      [@ZelenskyyUa]     Netherlands             #China
# 3                  []     Netherlands            #Taiwan
# 4  [@ChinaUncensored]  Ayent, Schweiz         #XiJinping
#
#   flattened_user_mentions
# 0              @i_ameztoy
# 1           @IndoPac_Info
# 2            @ZelenskyyUa
# 3        @ChinaUncensored
# 4         @benedictrogers

# %% [markdown]
# ## Plot of the Top 10 UserMentions

# %%
tweet_data['flattened_user_mentions'].value_counts()[:10].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Text Preprocessing

# %%
#text Preprocessing
tweet_data['original_text'] = tweet_data['original_text'].astype(str)
tweet_data['original_text'] = tweet_data['original_text'].apply(lambda x: x.lower())
tweet_data['original_text']= tweet_data['original_text'].apply(lambda x: x.translate(str.maketrans(' ', ' ', string.punctuation)))

# %%
plt.figure(figsize=(20, 10))
plt.imshow(WordCloud(width=1000,height=600,stopwords=STOPWORDS).generate(' '.join(tweet_data.original_text .values)))
plt.axis('off')
plt.title('Most Frequent Words In Our Tweets, the word',fontsize=16)
plt.show()

# %% [markdown]
# - The word **___taiwan, china, indopacinfo, & spokesperson___** apears are the top 3 words that appear frequently
# - The words **taiwan** and **china** are the most hashtagged words
# - The word **indopacinfo** and **spokesperson** are the most mentioned name

# %% [markdown]
# ## 3. Data preparation
# ### Data cleaning
# - Before further use of the data using the clean_tweets_dataframe python file
#  1. Drop unwanted rows
#  2. Convert to datetime - for created_at columns
#  3. Convert to numbers for
#   - polarity, subjectivity, retweet_count, favorite_count, followers_count, friends_count
#  4. Fill all the none value in possibly_sensitive with False
#  5. Drop all the rows with none value
#  6. Remove user stopwords, links,special characters, mentions, and hashtag from the tweet text
#  7. Expand text such you're to you are
#  8. Convert the tweet text lower-case
#  9. Finally change the original_text to clean_text - column rename

# %%
import nltk
nltk.download('stopwords')
clean_tweet = Clean_Tweets(tweet_data)
clean_tweet_data = clean_tweet.clean_tweet(tweet_data, save_csv=False)
clean_tweet_data.head()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\win\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
#                  created_at               source  \
# 0 2022-08-07 22:31:20+00:00  twitter for android
# 1 2022-08-07 22:31:16+00:00  twitter for android
# 2 2022-08-07 22:31:07+00:00  twitter for android
# 3 2022-08-07 22:31:06+00:00  twitter for android
# 4 2022-08-07 22:31:04+00:00   twitter for iphone
#
#                                           clean_text      polarity  \
# 0  iameztoy extra random image let us focus one s... -1.250000e-01
# 1  indopacinfo chinas media explains military rea... -1.000000e-01
# 2  china even cut communication anwer phonecalls ...  0.000000e+00
# 3  putin xijinping told friend taiwan vassal stat...  1.000000e-01
# 4  chinauncensored sorry thought taiwan independe... -6.938894e-18
#
#    subjectivity lang  favorite_count  retweet_count original_author  \
# 0      0.190625   en               0              2       i_ameztoy
# 1      0.100000   en               0            201           ziisq
# 2      0.000000   en               0              0       fin21free
# 3      0.350000   en               0              0       fin21free
# 4      0.556250   en               0            381  vizzinidolores
#
#    followers_count  friends_count  possibly_sensitive           hashtags  \
# 0            20497           2621               False       [#city, #ta]
# 1               65            272               False  [#china, #taiwan]
# 2               85            392               False       [#xijinping]
# 3               85            392               False       [#xijinping]
# 4              910           2608               False
#
#         user_mentions           place flattened_hashtags  \
# 0        [@i_ameztoy]                              #City
# 1     [@indopac_info]                                #Ta
# 2      [@zelenskyyua]     netherlands             #China
# 3                         netherlands            #Taiwan
# 4  [@chinauncensored]  ayent, schweiz         #XiJinping
#
#   flattened_user_mentions
# 0              @i_ameztoy
# 1           @IndoPac_Info
# 2            @ZelenskyyUa
# 3        @ChinaUncensored
# 4         @benedictrogers

# %%
missing_count = clean_tweet_data.isnull().sum()
print(f"Missing value(s) count: \n{missing_count}")
# Out:
# Missing value(s) count:
# created_at                 0
# source                     0
# clean_text                 0
# polarity                   0
# subjectivity               0
# lang                       0
# favorite_count             0
# retweet_count              0
# original_author            0
# followers_count            0
# friends_count              0
# possibly_sensitive         0
# hashtags                   0
# user_mentions              0
# place                      0
# flattened_hashtags         0
# flattened_user_mentions    0
# dtype: int64

# %% [markdown]
# # Users related Analysis
#
# - User related details like:
#
#  1. The total number of users in the dataset
#  2. The number of tweets per users
#  3. Users with the most liked, shared tweets
#  4. The sentiment of the tweets with the most interactions (likes and retweets)

# %%
users_count = clean_tweet_data['original_author'].value_counts()
print(len(users_count), "users")
print("Number of posts per user")
users_count[:10].plot(kind='bar')
# Out:
# 13433 users
# Number of posts per user
# <AxesSubplot:>

# %%
hot_tweets = clean_tweet_data[tweet_data['favorite_count']>200]
hot_tweets['favorite_count'].plot.hist(figsize=(12, 8))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %% [markdown]
# ## Identification of soruce of the tweets
#
# we can get the top 3 sources of the twitter data are android, web, and iphone

# %%
clean_tweet_data['source'].value_counts()[:10].plot(kind='bar', figsize=(10, 6), fontsize=15)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Sentimental Analysis
# - create score from the polarity
# - use the score as target value

# %%
pre_processor = DataPreparation(clean_tweet_data)
clean_tweet_data_score = pre_processor.create_score(clean_tweet_data)
clean_tweet_data_score.columns
# Out:
# Index(['created_at', 'source', 'clean_text', 'polarity', 'subjectivity',
#        'lang', 'favorite_count', 'retweet_count', 'original_author',
#        'followers_count', 'friends_count', 'possibly_sensitive', 'hashtags',
#        'user_mentions', 'place', 'flattened_hashtags',
#        'flattened_user_mentions', 'score'],
#       dtype='object')

# %%
#barchart
sentiment_count = clean_tweet_data_score['score'].value_counts()#.plot(kind='bar')
keys =list(sentiment_count.keys())
counts = [item for key,item in sentiment_count.items()]

fig, ax = plt.subplots(1,2)

ax[0].bar(keys, counts, tick_label = keys,
        width = 0.8, color = ['blue', 'green','orange'])
ax[0].set_title('barchart')

ax[1].pie(counts, labels = keys, 
          startangle=90, 
          shadow = True,
          colors = ['blue', 'green','orange'],
          radius = 1.2)
ax[1].set_title('piechart')
plt.subplots_adjust(left=0.2, right=0.99,
                    bottom=0.2, top=0.6, 
                    wspace=0.6, hspace=0.4)

# %%
common_source =clean_tweet_data[clean_tweet_data['source'].isin( ['twitter for android',
                                                 'twitter web app',
                                                 'twitter for iphone' ])]
common_source.groupby('source')['score'].value_counts().plot.pie(figsize=(12, 10), fontsize=15)
# Out:
# <AxesSubplot:ylabel='score'>

# %% [markdown]
# - Most of the tweets coming from android, web app, and iphone are neutral
# - the number of positive tweets are less than that of the negative tweets

# %%
common_source.groupby('source')['score'].value_counts().plot.bar(color=['teal', 'green', 'blue'],
                                                             figsize=(12, 10), 
                                                             fontsize=15,
                                                             title="Common tweet sources polarity")
# Out:
# <AxesSubplot:title={'center':'Common tweet sources polarity'}, xlabel='source,score'>

# %% [markdown]
# # additonal preprocess to convert the score value to class 1 or 0
# - Remove rows from cleanTweet where  𝐩𝐨𝐥𝐚𝐫𝐢𝐭𝐲   =0  (i.e where  𝐬𝐜𝐨𝐫𝐞  = Neutral) and reset the frame index.
#
# - Construct a column  𝐬𝐜𝐨𝐫𝐞𝐦𝐚𝐩  Use the mapping {'positive':1, 'negative':0} on the  𝐬𝐜𝐨𝐫𝐞  column
#
# - Create feature and target variables (X,y) from  𝐜𝐥𝐞𝐚𝐧-𝐭𝐞𝐱𝐭  and  𝐬𝐜𝐨𝐫𝐞𝐦𝐚𝐩  columns respectively.
#
# - Use train_test_split function to construct (X_train, y_train) and (X_test, y_test) from (X,y)
#
# - Build an SGDClassifier model from the vectorize train text data. Use CountVectorizer() with a  trigram  parameter.
# - Evaluate your model on the test data.

# %%
clean_tweet_data_scoremap = pre_processor.create_scoremap(clean_tweet_data_score)
clean_tweet_data_scoremap.columns
# Out:
# Index(['created_at', 'source', 'clean_text', 'polarity', 'subjectivity',
#        'lang', 'favorite_count', 'retweet_count', 'original_author',
#        'followers_count', 'friends_count', 'possibly_sensitive', 'hashtags',
#        'user_mentions', 'place', 'flattened_hashtags',
#        'flattened_user_mentions', 'score', 'scoremap'],
#       dtype='object')

# %%
clean_tweet_data_scoremap.head()
# Out:
#                  created_at               source  \
# 0 2022-08-07 22:31:20+00:00  twitter for android
# 1 2022-08-07 22:31:16+00:00  twitter for android
# 3 2022-08-07 22:31:06+00:00  twitter for android
# 4 2022-08-07 22:31:04+00:00   twitter for iphone
# 5 2022-08-07 22:31:02+00:00  twitter for android
#
#                                           clean_text      polarity  \
# 0  iameztoy extra random image let us focus one s... -1.250000e-01
# 1  indopacinfo chinas media explains military rea... -1.000000e-01
# 3  putin xijinping told friend taiwan vassal stat...  1.000000e-01
# 4  chinauncensored sorry thought taiwan independe... -6.938894e-18
# 5  benedictrogers must let happen must ready must...  2.000000e-01
#
#    subjectivity lang  favorite_count  retweet_count  original_author  \
# 0      0.190625   en               0              2        i_ameztoy
# 1      0.100000   en               0            201            ziisq
# 3      0.350000   en               0              0        fin21free
# 4      0.556250   en               0            381   vizzinidolores
# 5      0.500000   en               0             36  gracech15554845
#
#    followers_count  friends_count  possibly_sensitive           hashtags  \
# 0            20497           2621               False       [#city, #ta]
# 1               65            272               False  [#china, #taiwan]
# 3               85            392               False       [#xijinping]
# 4              910           2608               False
# 5              207             54               False          [#taiwan]
#
#         user_mentions                place flattened_hashtags  \
# 0        [@i_ameztoy]                                   #City
# 1     [@indopac_info]                                     #Ta
# 3                              netherlands            #Taiwan
# 4  [@chinauncensored]       ayent, schweiz         #XiJinping
# 5   [@benedictrogers]  melbourne, victoria         #XiJinping
#
#   flattened_user_mentions     score  scoremap
# 0              @i_ameztoy  negative         0
# 1           @IndoPac_Info  negative         0
# 3        @ChinaUncensored  positive         1
# 4         @benedictrogers  negative         0
# 5          @TGTM_Official  positive         1

# %%
X,y = np.array(clean_tweet_data_scoremap['clean_text'],dtype='unicode'), clean_tweet_data_scoremap['scoremap']
from sklearn.feature_extraction.text import CountVectorizer
vectorizer = CountVectorizer(ngram_range=(3,3))
X = vectorizer.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

clf = SGDClassifier(max_iter=1000, tol=1e-3)
model = clf.fit(X_train, y_train)

# %% [markdown]
# -

# %%
model.score(X_test,y_test)
# Out:
# 0.9292200232828871
